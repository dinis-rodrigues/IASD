# %%
c = var('room'+'1')
print(c)
b=dict(c = True, Mary=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bafdb5f1c546> in <module>
# ----> 1 c = var('room'+'1')
#       2 print(c)
#       3 b=dict(c = True, Mary=True)
#
# NameError: name 'var' is not defined

# %%
b
# Out:
# {'c': True, 'Mary': True}

# %%
T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9c3dfd791d39> in <module>
# ----> 1 room+1
#
# NameError: name 'room' is not defined

# %%
a = []
a.append((1,2))

# %%
a
# Out:
# [(1, 2)]

# %%
import itertools

# %%
bin_table = list(itertools.product([False, True], repeat=2))
print(bin_table)
# Out:
# [(False, False), (False, True), (True, False), (True, True)]

# %%
for row in bin_table:
    print('This is the row -> ', row)
    print('This is the corresponding row[0] -> ', row[0], '\n')
# Out:
# This is the row ->  (False, False)
# This is the corresponding row[0] ->  False
#
# This is the row ->  (False, True)
# This is the corresponding row[0] ->  False
#
# This is the row ->  (True, False)
# This is the corresponding row[0] ->  True
#
# This is the row ->  (True, True)
# This is the corresponding row[0] ->  True

# %%
for row in bint:
    if all(item == False for item in row):
        print(row)
        print('yes')
# Out:
# (False, False)
# yes

# %%
T,F = True, False
b= {(T, T): 0.95, (T, F): 0.94, (F, T): 0.29, (F, F): 0.001}
b[(T,T)]
# Out:
# 0.95

# %%
d = {}
d[False] = 0.1

# %%
d
# Out:
# {False: 0.1}

# %%
c = [1, 2]
if c:
    print('yes')
# Out:
# yes

# %%
dict(s1_1 = False, s2_1 = False, s1_2 = False, s3_2 = False)
# Out:
# {'s1_1': False, 's2_1': False, 's1_2': False, 's3_2': False}

# %%
r = dict(s1_1 = 1, s2_1 = 2, s1_2 = 3, s3_2 = 4)
max(r, key=r.get)
# Out:
# 's3_2'
